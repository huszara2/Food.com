# %% [markdown]
# # Data Cleaning
# Here, we convert types and units for a more usable data frame. First, import packages and csv.

# %%
import pandas as pd
import numpy as np

# %%
#load csv file
food_df=pd.read_csv('data/recipes.csv',encoding='utf-8')

# %% [markdown]
# ## Convert prep time, cook time, and total time to integer (minutes)
# It will be more useful to have all of our times be given in minutes, rather than a mix of minutes and hours.

# %%
#Convert to minutes
#get hours
hours_series=food_df['CookTime'].replace(to_replace='PT(?:(\d+)H)?(?:(\d+)M)?',value=r"\1", regex=True)
#replace empty string with 0
hours_series.replace(r'^\s*$', 0, regex=True,inplace=True)

#get minutes
minutes_series=food_df['CookTime'].replace(to_replace='PT(?:(\d+)H)?(?:(\d+)M)?',value=r"\2", regex=True)
#replace empty string with 0
minutes_series.replace(r'^\s*$', 0, regex=True,inplace=True)

#replace NaNs (no cooktime)
hours_series[hours_series.isnull()]=0
minutes_series[minutes_series.isnull()]=0

#convert to minutes
food_df['CookTime']=minutes_series.astype(int)+60*hours_series.astype(int)

# %%
#Do the same with PrepTime
#two recipes say negative prep time, should be positive
#print(food_df[food_df['PrepTime'].str.contains("-")])
food_df['PrepTime']=food_df['PrepTime'].str.replace('-','')

#Convert to minutes
#get hours
hours_series=food_df['PrepTime'].replace(to_replace='PT(?:(\d+)H)?(?:(\d+)M)?(?:(\d+)S)?',value=r"\1", regex=True)
#replace empty string with 0
hours_series.replace(r'^\s*$', 0, regex=True,inplace=True)

#get minutes, remove negative entries
minutes_series=food_df['PrepTime'].replace(to_replace='PT(?:(\d+)H)?(?:(\d+)M)?(?:(\d+)S)?',value=r"\2", regex=True)
#replace empty string with 0
minutes_series.replace(r'^\s*$', 0, regex=True,inplace=True)

#get seconds - Did not end up needing, all were 0.
#seconds_series=food_df['PrepTime'].replace(to_replace='PT(?:(\d+)H)?(?:(\d+)M)?(?:(\d+)S)?',value=r"\3", regex=True)
#replace empty string with 0
#seconds_series.replace(r'^\s*$', 0, regex=True,inplace=True)


#replace NaNs (no cooktime)
hours_series[hours_series.isnull()]=0
minutes_series[minutes_series.isnull()]=0
#seconds_series[seconds_series.isnull()]=0

#convert to minutes
food_df['PrepTime']=minutes_series.astype(int)+60*hours_series.astype(int)

# %%
#Finally, do the same with total time.
#remove negative preptime
#print(food_df[food_df['TotalTime'].str.contains("-")])
food_df['TotalTime']=food_df['TotalTime'].str.replace('-','')

#Convert to minutes
#get hours
hours_series=food_df['TotalTime'].replace(to_replace='PT(?:(\d+)H)?(?:(\d+)M)?(?:(\d+)S)?',value=r"\1", regex=True)
#replace empty string with 0
hours_series.replace(r'^\s*$', 0, regex=True,inplace=True)

#get minutes
minutes_series=food_df['TotalTime'].replace(to_replace='PT(?:(\d+)H)?(?:(\d+)M)?(?:(\d+)S)?',value=r"\2", regex=True)
#replace empty string with 0
minutes_series.replace(r'^\s*$', 0, regex=True,inplace=True)

#replace NaNs (no cooktime)
hours_series[hours_series.isnull()]=0
minutes_series[minutes_series.isnull()]=0

#convert to minutes
food_df['TotalTime']=minutes_series.astype(int)+60*hours_series.astype(int)

# %% [markdown]
# ## Add columns
# We will add columns for number of images, number of ingredients, number of steps, and will clean the keywords column.
#
# ### Number of Images.
# Index 264469 has "NaN" in images column instead of character(0), and needs to be treated sepatately.

# %%
#If the image entry is character(0), no images, returns 0. Else, returns number of images (separated by ", ")
food_df['NumImages']=(food_df['Images']!='character(0)')*(1+food_df['Images'].str.count('", "'))
food_df.loc[264469,'NumImages']=0
food_df['NumImages']=food_df['NumImages'].astype(int)

# %% [markdown]
# ### Number of Ingredients.

# %%
food_df['RecipeIngredientParts']=food_df['RecipeIngredientParts'].str.strip('c').str.strip('(').str.strip(')')
food_df['NumIngredients']=(food_df['RecipeIngredientParts']!='character(0)')*(1+food_df['RecipeIngredientParts'].str.count('", "'))

# %% [markdown]
# ### Number of Steps.

# %%
food_df['RecipeInstructions']=food_df['RecipeInstructions'].str.strip('c').str.strip('(').str.strip(')')
food_df['NumSteps']=(food_df['RecipeInstructions']!='character(0)')*(1+food_df['RecipeInstructions'].str.count('", "'))

# %% [markdown]
# ### Clean Keywords and Quantities
# We get rid of the c() around the keywords and ingredient quantities.

# %%
food_df['Keywords']=food_df['Keywords'].str.strip('c').str.strip('(').str.strip(')')
food_df['RecipeIngredientQuantities']=food_df['RecipeIngredientQuantities'].str.strip('c').str.strip('(').str.strip(')')

# %% [markdown]
# ## DatePublished to DateTime

# %%
food_df['DatePublished']=pd.to_datetime(food_df['DatePublished'],format='%Y-%m-%dT%H:%M:%SZ')

# %%
pd.set_option("display.max_columns", 100)
food_df.head(20)
# Out:
#     RecipeId                                               Name    AuthorId  \
# 0      12021                       Swirled Cranberry Cheesecake       14386
# 1     348900                                  Chicken Basquaise      287420
# 2     102996                               Brandy Alexander Pie       98467
# 3     373435                             Creole Sauteed Cabbage       96177
# 4     299106                            Hyderabad Chicken Curry      409106
# 5      15410                                   Learn Your Abc's       10649
# 6     181352                                Budbud Kabog Recipe      261327
# 7      94316                            Turkey Salad Polynesian      129958
# 8     357430         Saut&eacute;ed Beef in Paprika Cream Sauce      865936
# 9     253593                        Duck Cassoulet  (Crock Pot)      283251
# 10    464990                                    Ham and Egg Pie      107135
# 11    215003                             Beam Me up Scottie Mac      324390
# 12    112419       Bow Ties With Asparagus Cream and Prosciutto       59473
# 13    533414  Creamy Tomato Basil Zucchini &quot;Linguini&quot;  2000832839
# 14    194249                                  Pumpkin Pecan Pie       36187
# 15    122399                   Pistachio Nut and Orange Cookies       36476
# 16    125996                    Potted Cheese and Garlic Spread      190807
# 17    413409                         Easy Shredded Mexican Beef      890229
# 18    214288                                       Zesty Hummus      386693
# 19    459782                                    Comfort Goulash      330889
#
#              AuthorName  CookTime  PrepTime  TotalTime       DatePublished  \
# 0            Divinemom5       120        15        135 2001-09-23 15:35:00
# 1          English_Rose        40        20         60 2009-01-11 13:12:00
# 2               Scout33       120        30        150 2004-10-30 20:00:00
# 3             BakinBaby        20         3         23 2009-05-20 20:13:00
# 4          Brian Holley        70        10         80 2008-04-17 02:13:00
# 5              Ben Ross         0         5          5 2001-12-07 09:56:00
# 6             gailinsik        60       120        180 2006-08-10 14:29:00
# 7               Bobtail         0        30         30 2004-06-25 20:00:00
# 8            threeovens        15        10         25 2009-02-23 11:49:00
# 9              dicentra       360        20        380 2007-09-18 22:27:00
# 10            Dienia B.        60        10         70 2011-09-26 20:21:00
# 11            cookiedog         0         5          5 2007-03-04 15:47:00
# 12               Fluffy        12        10         22 2005-03-01 19:59:00
# 13               Janice        20        20         40 2017-09-05 20:49:00
# 14               dojemi        50         0         50 2006-11-06 19:50:00
# 15              Sabra_1        20        10         30 2005-05-16 15:59:00
# 16              Semra22         0        10         10 2005-06-14 14:28:00
# 17   kittycatonline.com       240        20        260 2010-02-17 10:23:00
# 18  Sesquipedalian Sapp        15        10         25 2007-02-27 23:46:00
# 19         bunny_rabbit        40         5         45 2011-07-01 13:26:00
#
#                                           Description  \
# 0   Make and share this Swirled Cranberry Cheeseca...
# 1   At the very time you are serving stir in some ...
# 2   A congealed version of the Frozen Brandy Alexa...
# 3   Andouille or smoke sausage sauteed with cabbag...
# 4   A slightly sweeter chicken curry due to the us...
# 5   This is a very old cocktail. This is one of my...
# 6   Make and share this Budbud Kabog Recipe recipe...
# 7   This is another delicious warm weather salad f...
# 8   A quick and easy Hungarian style main dish.  A...
# 9   Make and share this Duck Cassoulet  (Crock Pot...
# 10  Uses canned milk and regular milk; simple easy...
# 11  Make and share this Beam Me up Scottie Mac rec...
# 12  Make and share this Bow Ties With Asparagus Cr...
# 13  Make and share this Creamy Tomato Basil Zucchi...
# 14  I just received this via email from a local ma...
# 15  Make and share this Pistachio Nut and Orange C...
# 16  Make and share this Potted Cheese and Garlic S...
# 17  Slow cooker or dutch oven Mexican shredded bee...
# 18  Party-sized batch!  A very flavorful twist on ...
# 19  Make and share this Comfort Goulash recipe fro...
#
#                                                Images   RecipeCategory  \
# 0   "https://img.sndimg.com/food/image/upload/w_55...       Cheesecake
# 1                                        character(0)   Chicken Breast
# 2                                        character(0)          Gelatin
# 3   c("https://img.sndimg.com/food/image/upload/w_...        Vegetable
# 4                                        character(0)          Curries
# 5                                        character(0)        Beverages
# 6   c("https://img.sndimg.com/food/image/upload/w_...        Breakfast
# 7   c("https://img.sndimg.com/food/image/upload/w_...  Low Cholesterol
# 8                                        character(0)             Meat
# 9                                        character(0)             Stew
# 10  "https://img.sndimg.com/food/image/upload/w_55...      Savory Pies
# 11  "https://img.sndimg.com/food/image/upload/w_55...        Beverages
# 12                                       character(0)        Vegetable
# 13                                       character(0)          Chicken
# 14                                       character(0)          Dessert
# 15                                       character(0)          Dessert
# 16                                       character(0)          Spreads
# 17                                       character(0)             Meat
# 18                                       character(0)            Beans
# 19                                       character(0)    One Dish Meal
#
#                                              Keywords  \
# 0   "Dessert", "Cheese", "Fruit", "Winter", "Chris...
# 1   "Chicken Thigh & Leg", "Chicken", "Poultry", "...
# 2                              "Dessert", "< 4 Hours"
# 3                               "Creole", "< 30 Mins"
# 4   "Chicken", "Poultry", "Meat", "Asian", "Indian...
# 5                      "< 15 Mins", "No Cook", "Easy"
# 6   "Grains", "Filipino", "Asian", "For Large Grou...
# 7   "Healthy", "Thanksgiving", "< 30 Mins", "Begin...
# 8                       "Very Low Carbs", "< 30 Mins"
# 9   "Duck Breasts", "Duck", "Pork", "Poultry", "Be...
# 10  "Breakfast", "Ham", "Pork", "Cheese", "Meat", ...
# 11                       "Sweet", "< 15 Mins", "Easy"
# 12                                        "< 30 Mins"
# 13                     "Poultry", "Meat", "< 60 Mins"
# 14       "Fruit", "Nuts", "Thanksgiving", "< 60 Mins"
# 15  "Lunch/Snacks", "Cookie & Brownie", "< 30 Mins...
# 16  "Cheese", "Very Low Carbs", "High Protein", "H...
# 17  "Very Low Carbs", "Beginner Cook", "Easy", "In...
# 18  "Southwest Asia (middle East)", "Asian", "Lact...
# 19  "Meat", "Toddler Friendly", "Kid Friendly", "<...
#
#                            RecipeIngredientQuantities  \
# 0   "2 1/4", "1/4", "1", "2", "1/4", "3", "1", "1"...
# 1   "1", "1", "1", "1", "3", "2/3", "1 1/4", "10",...
# 2           "1", "1", "1/4", "1 1/2", "1/4", "2", "2"
# 3                 "1", "1/2", "1", "1", "1", "1", "1"
# 4   "1", "2", "2", "2", "2", "2", "2", "1", "3", "...
# 5                                    "15", "15", "15"
# 6                    "3", NA, NA, "2", NA, "3/4", "2"
# 7   "8", "2", "3/4", "3/4", "1/4", "1", "1", "1/2"...
# 8         "1 1/4", NA, "2", "2", "1", "2", "1/2", "1"
# 9   "1", "1", "1", "3", "1", "1/2", "1", "1", "1",...
# 10                   "1", "1", "4", "1/4", "1/4", "1"
# 11                                  "1/2", "1/2", "1"
# 12                "2", "1", "1", "1", "1", "1/2", "2"
# 13  "2", "1", "1", "1", "1", "1/2", "1/2", "1/2", ...
# 14  "1", "1", "1/3", "1", "1", "2/3", "1/2", "2", ...
# 15          "500", "1", "440", "1", "100", "1", "500"
# 16   "2", "1/4", "1/2", "1", "1/2", "1/4", "1", "1/4"
# 17                       "2", "1", "2", "2", "1", "1"
# 18  "3", "1/4", "2", "1/2", "1/2", "1", "1/4", "1/...
# 19  "1", "1 -2", "1", "1", "1", "2", "3", "1 1/2",...
#
#                                 RecipeIngredientParts  AggregatedRating  \
# 0   "butter", "whole berry cranberry sauce", "cinn...               5.0
# 1   "chicken thighs", "chicken breasts", "olive oi...               NaN
# 2   "9-inch graham cracker crusts", "unflavored ge...               5.0
# 3   "cabbage", "andouille sausage", "onion", "baco...               5.0
# 4   "onion", "ghee", "butter", "garlic cloves", "g...               5.0
# 5         "Amaretto", "Baileys Irish Cream", "cognac"               NaN
# 6   "fresh coconut", "warm water", "water", "sugar...               4.0
# 7   "mostaccioli pasta", "celery", "walnuts", "gre...               5.0
# 8   "paprika", "butter", "onion", "green bell pepp...               NaN
# 9   "pork sausage link", "whole cloves", "onion", ...               NaN
# 10  "milk", "evaporated milk", "eggs", "ham", "che...               5.0
# 11           "Bacardi 151 rum", "Baileys Irish Cream"               NaN
# 12  "salt", "salt", "asparagus", "farfalle pasta",...               NaN
# 13  "zucchini", "salt", "olive oil", "chicken brea...               NaN
# 14  "pumpkin puree", "granulated sugar", "egg", "p...               NaN
# 15  "butter", "egg", "sugar", "pistachio nuts", "o...               NaN
# 16  "cheddar cheese", "beer", "onion powder", "gar...               NaN
# 17        "beef", "stewed tomatoes", "water", "onion"               5.0
# 18  "garbanzo beans", "garlic cloves", "lime juice...               5.0
# 19  "ground beef", "garlic clove", "onion", "green...               NaN
#
#     ReviewCount  Calories  FatContent  SaturatedFatContent  \
# 0           9.0    4575.7       304.1                184.9
# 1           NaN    1073.2        64.7                 18.8
# 2           1.0     352.3        24.0                 11.8
# 3           5.0     102.4         4.0                  2.2
# 4           1.0     723.2        26.6                 12.3
# 5           NaN      51.6         2.5                  1.5
# 6           3.0      63.1         4.2                  3.6
# 7           3.0     353.6        16.4                  3.3
# 8           NaN     637.1        51.0                 26.6
# 9           NaN     516.1        29.0                  9.4
# 10          2.0     385.8        25.1                 10.7
# 11          NaN     134.4         4.9                  3.0
# 12          NaN     463.1        17.8                 10.6
# 13          NaN     413.1        28.4                  8.4
# 14          NaN     398.5        20.4                  5.8
# 15          NaN     221.6        13.0                  7.5
# 16          NaN     544.9        48.6                 30.7
# 17          1.0     229.6         9.3                  4.1
# 18          1.0     163.4         4.0                  0.5
# 19          NaN     467.3        18.4                  7.0
#
#     CholesterolContent  SodiumContent  CarbohydrateContent  FiberContent  \
# 0               1716.5         2756.6                404.4           7.3
# 1                305.3          834.3                 36.0           2.7
# 2                 61.1          189.8                 28.4           0.5
# 3                  9.0           83.6                 15.9           6.0
# 4                326.0          270.1                 10.1           2.6
# 5                  9.2           14.5                  3.3           0.0
# 6                  0.0           49.1                  6.2           1.4
# 7                 34.6          290.2                 36.6           3.0
# 8                191.8          143.9                 10.5           2.2
# 9                 60.2          619.5                 39.7          15.2
# 10               171.6          672.2                 20.3           1.1
# 11                18.0           28.8                  6.5           0.0
# 12                59.1         2855.6                 61.2           4.0
# 13                68.4         2286.5                 12.3           3.3
# 14                90.8          176.7                 53.5           1.4
# 15                36.6           84.1                 24.7           0.8
# 16               143.7          693.7                  3.3           0.2
# 17                99.8          215.7                  4.7           0.7
# 18                 0.0          400.9                 27.0           5.4
# 19                77.1         1213.4                 44.6           3.2
#
#     SugarContent  ProteinContent  RecipeServings         RecipeYield  \
# 0          376.7            78.2             NaN  1 9-inch cheescake
# 1            4.6            69.1             4.0                 NaN
# 2           19.1             2.9             NaN                 NaN
# 3            9.1             3.4             4.0                 NaN
# 4            3.0           107.0             4.0                 NaN
# 5            3.1             0.4             1.0                 NaN
# 6            2.2             0.8           100.0                 NaN
# 7            9.2            16.7             8.0                 NaN
# 8            4.0            29.4             4.0                   4
# 9            4.3            25.1             8.0                 NaN
# 10           0.3            19.2             6.0                 NaN
# 11           6.2             0.9             1.0                 NaN
# 12           2.4            15.1             6.0                 NaN
# 13           7.2            28.9             2.0                 NaN
# 14          30.0             4.4             8.0                 NaN
# 15          13.2             2.4            35.0                 NaN
# 16           0.8            23.1             NaN          2 1/2 cups
# 17           2.2            32.5             NaN                 NaN
# 18           0.6             6.4            12.0              6 cups
# 19           9.2            30.0             NaN                 NaN
#
#                                    RecipeInstructions  NumImages  \
# 0   "Mix cookie crumbs and butter.", "Press onto b...          1
# 1   "Put a tablespoon of oil in a medium flameproo...          0
# 2   "Sprinkle gelatin over cold water in small sau...          0
# 3   "Fry bacon and sausage in a large skillet abou...          3
# 4   "Skin and joint the chicken, set aside.", "Hea...          0
# 5   "Layer your A, B and C in a shot glass.", "Tak...          0
# 6   "Preparation stage:", "Grate two of the mature...          6
# 7   "Cook pasta to desired doneness, drain and rin...          2
# 8   "Cut beef into strips, about 1/2 inch X 2 inch...          0
# 9   "In a large skillet, brown the sliced sausage ...          0
# 10  "Mix milk, evaporated milk, eggs, ham, and che...          1
# 11  "Chill rum.", "Then layer. Creme de Banana fir...          1
# 12  "In a large skillet bring 2 inches of water to...          0
# 13  "1. Use a peeler to thinly slice zucchini into...          0
# 14  "PREHEAT oven to 350°F.", "Combine pumpkin, su...          0
# 15  "PREHEAT OVEN 160oC.", "CREAM BUTTER & SUGAR B...          0
# 16  "Simply combine everything in a food processor...          0
# 17  "Get a Dutch oven (or a crock pot).", "Dice up...          0
# 18  "Cut off both ends of each clove of garlic and...          0
# 19  "Brown the beef in a large skillet over medium...          0
#
#     NumIngredients  NumSteps
# 0                9        20
# 1               12         7
# 2                6         7
# 3                6         4
# 4               14         5
# 5                3         3
# 6                5         8
# 7               10         5
# 8                7         3
# 9               13         5
# 10               5         3
# 11               2         2
# 12               7        10
# 13              14         5
# 14              11         7
# 15               6         4
# 16               9         2
# 17               4        11
# 18               7         7
# 19               7         6

# %% [markdown]
# ## Remove html artifacts.
#
# We have:
# + \&quot; instead of ",
# + \&eacute; instead of &eacute;,
# + \&ntilde; instead of &ntilde;,
# + and \&amp; instead of &,
# + etc.
#
# There is a package that will fix most of this for us. We are left with some artifacts - we deal with some of these remaining artifacts, looking for instances where we have both ";" and "&" leaves us with over 200 entries.

# %%
#There is a package that will do this for us:
from bs4 import BeautifulSoup
food_df['Name']=food_df['Name'].map(lambda text: BeautifulSoup(text, 'html.parser').get_text())

#food_df[food_df['Name'].str.contains(";")]

# %%
# fixes some html that wasn't replaced
food_df['Name']=food_df['Name'].str.replace('&amp;amp;','&')
food_df['Name']=food_df['Name'].str.replace('&amp;','&')
food_df['Name']=food_df['Name'].str.replace('&quot;','"')
food_df['Name']=food_df['Name'].str.replace('&eacute;','é')
food_df['Name']=food_df['Name'].str.replace('&amp;','&')
food_df['Name']=food_df['Name'].str.replace('&ntilde;','ñ')
food_df['Name']=food_df['Name'].str.replace('&oslash;','ø')
food_df['Name']=food_df['Name'].str.replace('&ccedil;','ç')
food_df['Name']=food_df['Name'].str.replace('&aacute;','á')
food_df['Name']=food_df['Name'].str.replace('&uacute;','ú')
food_df['Name']=food_df['Name'].str.replace('&uacute;','ú')
food_df['Name']=food_df['Name'].str.replace('&ndash;','–')
food_df['Name']=food_df['Name'].str.replace('&agrave;','à')

#fix apostrophe's
food_df['Name']=food_df['Name'].str.replace('&#039;','\'')

# %%
food_df.loc[51607,'Name']
# Out:
# "Spinach Pasta Salad Recipe | Kathy's Vegan Kitchen"

# %%
print(food_df[(food_df['Name'].str.contains(";"))&(food_df['Name'].str.contains("&"))].size)
food_df[(food_df['Name'].str.contains(";"))&(food_df['Name'].str.contains("&"))]
# Out:
# 248
#         RecipeId                                               Name  AuthorId  \
# 12909     421951  Yummy Korean Seafood Pancakes Haemul Pajeon (&...   1604498
# 31962     254886  Pumpkin Soup With Red Cabbage and Cumin Seeds ...    594771
# 126226    157753                     P&#260;czki (Polish Doughnuts)    200356
# 152162    189503   Sparkling Wine Cocktail;  Raspberries & Chambord    232669
# 177548    179331                Better Than &#8219;beef’ Stroganoff    290499
# 369360    465368         Sausage & Sage Pierogies; the Heaping Bowl    772128
# 394399    390718  Korean Seasoned Potatoes (&#44048;&#51088; &#5...     93698
# 413344    399933  Squash, Chickpea & Red Lentil Stew (Healthy; S...    890605
#
#             AuthorName  CookTime  PrepTime  TotalTime       DatePublished  \
# 12909       donoteatme        10        10         20 2010-04-27 10:38:00
# 31962    blinkinglemon        30        20         50 2007-09-24 19:26:00
# 126226        Anka4505       120        20        140 2006-02-27 18:34:00
# 152162          Manami       120        15        135 2006-10-08 20:22:00
# 177548     Vegan Freak        20        15         35 2006-07-26 11:44:00
# 369360      madriley61        10         5         15 2011-10-02 14:54:00
# 394399       Andy Wold         0        20         20 2009-09-17 14:44:00
# 413344  GoldsmithLissa       600        20        620 2009-11-17 20:28:00
#
#                                               Description  \
# 12909   These seafood pancakes have been my favorite e...
# 31962   Make and share this Pumpkin Soup With Red Cabb...
# 126226  Make and share this P&amp;#260;czki (Polish Do...
# 152162  Make and share this Sparkling Wine Cocktail;  ...
# 177548  Short on time but looking for a hearty meal? T...
# 369360  This recipe is from a restaurant in East Atlan...
# 394399  Make and share this Korean Seasoned Potatoes (...
# 413344  Make and share this Squash, Chickpea &amp; Red...
#
#                                                    Images RecipeCategory  \
# 12909                                        character(0)         Onions
# 31962                                        character(0)      Vegetable
# 126226                                       character(0)         Breads
# 152162                                       character(0)      Beverages
# 177548                                       character(0)      Vegetable
# 369360                                       character(0)  One Dish Meal
# 394399  "https://img.sndimg.com/food/image/upload/w_55...         Potato
# 413344                                       character(0)  One Dish Meal
#
#                                                  Keywords  \
# 12909   "Peppers", "Vegetable", "Korean", "Asian", "We...
# 31962   "Turkish", "Southwest Asia (middle East)", "As...
# 126226  "European", "Hanukkah", "Brunch", "For Large G...
# 152162  "Raspberries", "Berries", "Fruit", "Brunch", "...
# 177548  "Lactose Free", "Vegan", "Egg Free", "Free Of....
# 369360  "Pork", "Potato", "Vegetable", "Meat", "Polish...
# 394399  "Vegetable", "Korean", "Asian", "Low Protein",...
# 413344                                        "Vegetable"
#
#                                RecipeIngredientQuantities  \
# 12909   "1", "1/4", "1", "2", "6", "5 -6", "5", "1", "...
# 31962   "3", "1", "3", "3", "1/2", "1", "3", "1/2", "1...
# 126226  "500", "5", "3", "1", "1", "5", "1", "50", "1"...
# 152162                       "1/2", "3 -4", "2", "12 2/3"
# 177548  "1", "1/2", "1", "1", "1", "2", "1/8", "1/4", ...
# 369360  "8", "2", "2", "8", "16", "4", "4", "1", "1", ...
# 394399               "2", "2", "2", "1", "2", "1 -2", "4"
# 413344  "3/4", "1", "2", "1", "1", "4", "2", "2", "1 1...
#
#                                     RecipeIngredientParts  AggregatedRating  \
# 12909   "all-purpose flour", "rice powder", "cold wate...               NaN
# 31962   "pumpkin", "onion", "olive oil", "garlic clove...               NaN
# 126226  "all-purpose flour", "dry yeast", "egg", "nonf...               NaN
# 152162  "fresh raspberry", "Chambord raspberry liquor"...               NaN
# 177548  "onion", "garlic powder", "pepper", "salt", "v...               NaN
# 369360  "mild Italian sausage", "granny smith apples",...               NaN
# 394399  "potatoes", "soy sauce", "sugar", "garlic", "s...               4.5
# 413344  "dried garbanzo beans", "carrots", "onion", "r...               3.0
#
#         ReviewCount  Calories  FatContent  SaturatedFatContent  \
# 12909           NaN     632.9        11.5                  3.4
# 31962           NaN     164.6        11.9                  2.2
# 126226          NaN     159.7         9.4                  2.0
# 152162          NaN     187.2         0.2                  0.0
# 177548          NaN     292.6        12.4                  1.6
# 369360          NaN     181.2         9.6                  5.8
# 394399          2.0     117.0         2.0                  0.3
# 413344          1.0     327.3         3.0                  0.4
#
#         CholesterolContent  SodiumContent  CarbohydrateContent  FiberContent  \
# 12909                423.0          149.6                103.3           5.8
# 31962                  4.0           22.2                 13.9           2.5
# 126226                29.7           17.6                 15.6           0.6
# 152162                 0.0            9.6                 12.7           2.0
# 177548                 0.0         1114.9                 23.4           6.5
# 369360                28.6           55.5                 17.4           2.5
# 394399                 0.0          510.4                 22.2           2.8
# 413344                 0.0          467.5                 65.3          13.6
#
#         SugarContent  ProteinContent  RecipeServings RecipeYield  \
# 12909            6.1            26.7             1.0   1 pancake
# 31962            4.7             3.3             4.0         NaN
# 126226           2.6             2.7            30.0         NaN
# 152162           7.3             0.5             2.0         NaN
# 177548           3.6            23.4             4.0         NaN
# 369360          11.0             3.4             4.0         NaN
# 394399           3.2             3.5             4.0         NaN
# 413344           9.9            16.0             NaN         NaN
#
#                                        RecipeInstructions  NumImages  \
# 12909   "In a large bowl mix flour, sweet rice powder,...          0
# 31962   "We cut the pumpkin you see above into two, to...          0
# 126226  "Combine yeast with half a cup of warm milk, a...          0
# 152162  "Gently stir together raspberries, Chambord, a...          0
# 177548  "Cook the pasta in boiling water until the des...          0
# 369360  "Heat 1 tablespoon vegetable oil or butter in ...          0
# 394399  "Peel potatoes and dice, placing in cold water...          1
# 413344  "Cover chickpeas in cold water by at least 2 i...          0
#
#         NumIngredients  NumSteps
# 12909               11         3
# 31962               14         3
# 126226               8        13
# 152162               3         4
# 177548               5         3
# 369360               8         4
# 394399               6         5
# 413344              12         4

# %%
#Turn Keywords into a list
food_df['KeywordsTemp']=food_df['Keywords'].str.replace('", ',',')
food_df['KeywordsTemp']=food_df['Keywords'].str.replace('"','')

food_df['KeywordsTemp']=food_df['KeywordsTemp'].astype(str).str.split(", ")

food_df['Keywords']=food_df['KeywordsTemp']
food_df=food_df.drop(columns=['KeywordsTemp'])

# %%
#Turn Ingredients into a list
food_df['RecipeIngredientPartsTemp']=food_df['RecipeIngredientParts'].str.replace('", ',',')
food_df['RecipeIngredientPartsTemp']=food_df['RecipeIngredientParts'].str.replace('"','')

food_df['RecipeIngredientPartsTemp']=food_df['RecipeIngredientPartsTemp'].astype(str).str.split(", ")

#food_df['RecipeIngredientParts']=food_df['RecipeIngredientPartsTemp']
#food_df=food_df.drop(columns=['RecipeIngredientPartsTemp'])
