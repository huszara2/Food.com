# %%
#Import packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split

# %%
#load csv file
food_df=pd.read_csv('data/recipes.csv')

# %%
#subset for training
food_train,food_test=train_test_split(food_df,train_size=.8)

# %%
#Comment to look at head
food_df.head(15)

#column names
#food_train.columns[:]

#food_train.describe()
# Out:
#     RecipeId                                               Name    AuthorId  \
# 0      12021                       Swirled Cranberry Cheesecake       14386
# 1     348900                                  Chicken Basquaise      287420
# 2     102996                               Brandy Alexander Pie       98467
# 3     373435                             Creole Sauteed Cabbage       96177
# 4     299106                            Hyderabad Chicken Curry      409106
# 5      15410                                   Learn Your Abc's       10649
# 6     181352                                Budbud Kabog Recipe      261327
# 7      94316                            Turkey Salad Polynesian      129958
# 8     357430         Saut&eacute;ed Beef in Paprika Cream Sauce      865936
# 9     253593                        Duck Cassoulet  (Crock Pot)      283251
# 10    464990                                    Ham and Egg Pie      107135
# ...

# %% [markdown]
# #Some histograms of our data.
# 1. We look at count of each individual rating. We see the overwhelming majority of reviews give $5$ to the recipe.
# 2. Now, let's look at how many reviews recipes get.

# %%
#Histogram for reviews (rating)
sns.histplot(data=food_train, x='AggregatedRating',binwidth=.5,stat='probability')
# Out:
# <AxesSubplot:xlabel='AggregatedRating', ylabel='Probability'>

# %%
#Histogram for number of reviews
sns.histplot(data=food_train, x='ReviewCount',binwidth=10,binrange=(0,100))
# Out:
# <AxesSubplot:xlabel='ReviewCount', ylabel='Count'>

# %%
#Crockpot vs instant pot (slow cooker, multi cooker, pressure cooker)
#Gluten Free
#Low Fat
#Chicken, Pork, Beef, Vegan, Vegitarian
